# %%
from pprint import pprint 

meu_dicionario = { "nome":"Matheus", "sobrenome": "Pietrobon", "idade": 43, "peso": 75, "filhos": "MC CATRA" }
pprint(meu_dicionario)


print(meu_dicionario["nome"])
print(meu_dicionario["idade"])
print(meu_dicionario["filhos"])
# Out:
# {'filhos': 'MC CATRA',
#  'idade': 43,
#  'nome': 'Matheus',
#  'peso': 75,
#  'sobrenome': 'Pietrobon'}
# Matheus
# 43
# MC CATRA
